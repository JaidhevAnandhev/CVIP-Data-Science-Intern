# %%
# !pip install librosa
# Out:
# Requirement already satisfied: librosa in c:\users\jayak\anaconda3\lib\site-packages (0.10.1)
# Requirement already satisfied: audioread>=2.1.9 in c:\users\jayak\anaconda3\lib\site-packages (from librosa) (3.0.1)
# Requirement already satisfied: numpy!=1.22.0,!=1.22.1,!=1.22.2,>=1.20.3 in c:\users\jayak\anaconda3\lib\site-packages (from librosa) (1.24.4)
# Requirement already satisfied: scipy>=1.2.0 in c:\users\jayak\anaconda3\lib\site-packages (from librosa) (1.11.1)
# Requirement already satisfied: scikit-learn>=0.20.0 in c:\users\jayak\anaconda3\lib\site-packages (from librosa) (1.3.0)
# Requirement already satisfied: joblib>=0.14 in c:\users\jayak\anaconda3\lib\site-packages (from librosa) (1.2.0)
# Requirement already satisfied: decorator>=4.3.0 in c:\users\jayak\appdata\roaming\python\python311\site-packages (from librosa) (5.1.1)
# Requirement already satisfied: numba>=0.51.0 in c:\users\jayak\anaconda3\lib\site-packages (from librosa) (0.57.1)
# Requirement already satisfied: soundfile>=0.12.1 in c:\users\jayak\anaconda3\lib\site-packages (from librosa) (0.12.1)
# Requirement already satisfied: pooch>=1.0 in c:\users\jayak\anaconda3\lib\site-packages (from librosa) (1.8.0)
# Requirement already satisfied: soxr>=0.3.2 in c:\users\jayak\anaconda3\lib\site-packages (from librosa) (0.3.7)
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\users\jayak\anaconda3\lib\site-packages (from librosa) (4.7.1)
# Requirement already satisfied: lazy-loader>=0.1 in c:\users\jayak\anaconda3\lib\site-packages (from librosa) (0.2)
# Requirement already satisfied: msgpack>=1.0 in c:\users\jayak\anaconda3\lib\site-packages (from librosa) (1.0.3)
# Requirement already satisfied: llvmlite<0.41,>=0.40.0dev0 in c:\users\jayak\anaconda3\lib\site-packages (from numba>=0.51.0->librosa) (0.40.0)
# Requirement already satisfied: platformdirs>=2.5.0 in c:\users\jayak\appdata\roaming\python\python311\site-packages (from pooch>=1.0->librosa) (3.1.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\jayak\appdata\roaming\python\python311\site-packages (from pooch>=1.0->librosa) (23.0)
# Requirement already satisfied: requests>=2.19.0 in c:\users\jayak\anaconda3\lib\site-packages (from pooch>=1.0->librosa) (2.31.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\jayak\anaconda3\lib\site-packages (from scikit-learn>=0.20.0->librosa) (2.2.0)
# Requirement already satisfied: cffi>=1.0 in c:\users\jayak\anaconda3\lib\site-packages (from soundfile>=0.12.1->librosa) (1.15.1)
# Requirement already satisfied: pycparser in c:\users\jayak\anaconda3\lib\site-packages (from cffi>=1.0->soundfile>=0.12.1->librosa) (2.21)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\jayak\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jayak\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\jayak\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jayak\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2023.7.22)

# %%
import pandas as pd
import numpy as np
import os
import seaborn as sns
import matplotlib.pyplot as plt
import librosa
import librosa.display
from IPython.display import Audio
import warnings
warnings.filterwarnings('ignore')

# %%
paths = []
labels = []
for dirname, _, filenames in os.walk(r'D:\Jaidhev\TESS Toronto emotional speech set data'):
    for filename in filenames:
        paths.append(os.path.join(dirname, filename))
        label = filename.split('_')[-1]
        label = label.split('.')[0]
        labels.append(label.lower())
    if len(paths) == 2800:
        break
print('Dataset is Loaded')
# Out:
# Dataset is Loaded

# %%
len(paths)
# Out:
# 2800

# %%
paths[:5]
# Out:
# ['D:\\Jaidhev\\TESS Toronto emotional speech set data\\OAF_angry\\OAF_back_angry.wav',
#  'D:\\Jaidhev\\TESS Toronto emotional speech set data\\OAF_angry\\OAF_bar_angry.wav',
#  'D:\\Jaidhev\\TESS Toronto emotional speech set data\\OAF_angry\\OAF_base_angry.wav',
#  'D:\\Jaidhev\\TESS Toronto emotional speech set data\\OAF_angry\\OAF_bath_angry.wav',
#  'D:\\Jaidhev\\TESS Toronto emotional speech set data\\OAF_angry\\OAF_bean_angry.wav']

# %%
labels[:5]
# Out:
# ['angry', 'angry', 'angry', 'angry', 'angry']

# %%
df = pd.DataFrame()
df['speech'] =paths
df['label'] = labels
df.head()
# Out:
#                                               speech  label
# 0  D:\Jaidhev\TESS Toronto emotional speech set d...  angry
# 1  D:\Jaidhev\TESS Toronto emotional speech set d...  angry
# 2  D:\Jaidhev\TESS Toronto emotional speech set d...  angry
# 3  D:\Jaidhev\TESS Toronto emotional speech set d...  angry
# 4  D:\Jaidhev\TESS Toronto emotional speech set d...  angry

# %%
df['label'].value_counts()
# Out:
# label
# angry      400
# disgust    400
# fear       400
# happy      400
# neutral    400
# ps         400
# sad        400
# Name: count, dtype: int64

# %%
sns.countplot(data=df, x='label')
# Out:
# <Axes: xlabel='label', ylabel='count'>

# %%
def waveplot(data, sr, emotion):
    plt.figure(figsize=(10,5))
    plt.title(emotion, size=20)
    librosa.display.waveshow(data, sr=sr)
    plt.show()
    
def spectrogram(data, sr, emotion):
    x = librosa.stft(data)
    xdb = librosa.amplitude_to_db(abs(x))
    plt.figure(figsize=(11,5))
    plt.title(emotion, size=20)
    librosa.display.specshow(xdb, sr=sr, x_axis='time', y_axis='hz')
    plt.colorbar()

# %%
emotion = 'fear'
path = np.array(df['speech'][df['label']==emotion])[1]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectrogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion = 'angry'
path = np.array(df['speech'][df['label']==emotion])[1]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectrogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion = 'disgust'
path = np.array(df['speech'][df['label']==emotion])[0]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectrogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion = 'neutral'
path = np.array(df['speech'][df['label']==emotion])[0]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectrogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion = 'ps'
path = np.array(df['speech'][df['label']==emotion])[0]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectrogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion = 'sad'
path = np.array(df['speech'][df['label']==emotion])[0]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectrogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion = 'happy'
path = np.array(df['speech'][df['label']==emotion])[0]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectrogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
def extract_mfcc(filename):
    y, sr = librosa.load(filename, duration=3, offset=0.5)
    mfcc = np.mean(librosa.feature.mfcc(y=y, sr=sr, n_mfcc=40).T, axis=0)
    return mfcc

# %%
extract_mfcc(df['speech'][0])
# Out:
# array([-3.96986206e+02,  7.74405365e+01, -1.95927906e+01, -2.16666889e+01,
#        -2.11275506e+00,  1.00753632e+01, -2.03667068e+01, -6.09244919e+00,
#        -7.21228313e+00, -5.57365894e-01, -1.83255327e+00,  2.02101514e-01,
#         7.27551103e-01,  1.31773770e+00,  2.88633752e+00,  2.85579133e+00,
#        -4.71292162e+00, -4.43651056e+00, -1.62115920e+00, -1.02398405e+01,
#        -7.55126143e+00, -1.79688025e+00, -7.03765202e+00,  9.43658447e+00,
#         8.35585499e+00,  2.17123604e+01,  1.92169895e+01,  2.03489265e+01,
#         1.34133663e+01,  8.33917141e+00,  3.94722402e-01,  5.11131477e+00,
#         9.56873894e+00,  5.45486784e+00,  2.50996375e+00, -1.82390726e+00,
#         4.86896276e+00,  9.31392288e+00,  2.08915043e+00, -1.90649128e+00],
#       dtype=float32)

# %%
X_mfcc = df['speech'].apply(lambda x: extract_mfcc(x))
X_mfcc
# Out:
# 0       [-396.9862, 77.44054, -19.59279, -21.666689, -...
# 1       [-465.73267, 98.77373, 0.65600896, -32.74544, ...
# 2       [-429.79196, 46.124, 1.5550478, -0.21709506, 2...
# 3       [-403.46118, 76.32369, -12.531774, -22.288858,...
# 4       [-434.05756, 77.4455, 10.8655, 16.092943, 8.04...
#                               ...
# 2795    [-553.2201, 89.83577, 27.215466, 16.407124, 19...
# 2796    [-589.23676, 96.20408, 36.96118, 15.014448, 28...
# 2797    [-533.41815, 85.43242, 27.791998, 19.307178, 2...
# 2798    [-548.6142, 110.16424, 31.910236, 12.572517, 2...
# 2799    [-549.2962, 102.374565, 32.268833, 26.261616, ...
# Name: speech, Length: 2800, dtype: object

# %%
X = [x for x in X_mfcc]
X = np.array(X)
X.shape
# Out:
# (2800, 40)

# %%
## input split
X = np.expand_dims(X, -1)
X.shape
# Out:
# (2800, 40, 1)

# %%
from sklearn.preprocessing import OneHotEncoder
enc = OneHotEncoder()
y = enc.fit_transform(df[['label']])

# %%
y.shape
# Out:
# (2800, 7)

# %% [markdown]
# # CREATE A LSTM MODEL

# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout

model = Sequential([
    LSTM(256, return_sequences=False, input_shape=(40,1)),
    Dropout(0.2),
    Dense(128, activation='relu'),
    Dropout(0.2),
    Dense(64, activation='relu'),
    Dropout(0.2),
    Dense(7, activation='softmax')
])

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_1 (LSTM)               (None, 256)               264192
#
#  dropout_3 (Dropout)         (None, 256)               0
#
#  dense_3 (Dense)             (None, 128)               32896
#
#  dropout_4 (Dropout)         (None, 128)               0
#
#  dense_4 (Dense)             (None, 64)                8256
#
#  dropout_5 (Dropout)         (None, 64)                0
#
#  dense_5 (Dense)             (None, 7)                 455
#
# =================================================================
# Total params: 305799 (1.17 MB)
# Trainable params: 305799 (1.17 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\users\jayak\anaconda3\lib\site-packages (2.14.0)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: tensorflow-intel==2.14.0 in c:\users\jayak\anaconda3\lib\site-packages (from tensorflow) (2.14.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\jayak\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (2.0.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\jayak\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in c:\users\jayak\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (23.5.26)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\jayak\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\jayak\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\jayak\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (3.9.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\jayak\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (16.0.6)
# Requirement already satisfied: ml-dtypes==0.2.0 in c:\users\jayak\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (0.2.0)
# Requirement already satisfied: numpy>=1.23.5 in c:\users\jayak\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (1.24.4)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\jayak\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (3.3.0)
# Requirement already satisfied: packaging in c:\users\jayak\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.14.0->tensorflow) (23.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\jayak\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (4.24.4)
# Requirement already satisfied: setuptools in c:\users\jayak\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (68.0.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\jayak\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.14.0->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\jayak\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (2.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\jayak\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (4.7.1)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in c:\users\jayak\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\jayak\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (0.31.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\jayak\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (1.59.0)
# Requirement already satisfied: tensorboard<2.15,>=2.14 in c:\users\jayak\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (2.14.1)
# Requirement already satisfied: tensorflow-estimator<2.15,>=2.14.0 in c:\users\jayak\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (2.14.0)
# Requirement already satisfied: keras<2.15,>=2.14.0 in c:\users\jayak\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (2.14.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\jayak\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.14.0->tensorflow) (0.38.4)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\jayak\anaconda3\lib\site-packages (from tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (2.23.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in c:\users\jayak\anaconda3\lib\site-packages (from tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\jayak\anaconda3\lib\site-packages (from tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (3.4.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\jayak\anaconda3\lib\site-packages (from tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\jayak\anaconda3\lib\site-packages (from tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\jayak\anaconda3\lib\site-packages (from tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (2.2.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\jayak\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\jayak\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\jayak\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\jayak\anaconda3\lib\site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\jayak\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jayak\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\jayak\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jayak\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\jayak\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (2.1.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\jayak\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\jayak\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (3.2.2)

# %%
pip install keras
# Out:
# Requirement already satisfied: keras in c:\users\jayak\anaconda3\lib\site-packages (2.14.0)Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.preprocessing import OneHotEncoder
enc = OneHotEncoder()
y1 = enc.fit_transform(df[['label']])

# %%
y1 = y1.toarray()
y1.shape
# Out:
# (2800, 7)

# %%
# Train the model
history = model.fit(X, y1, validation_split=0.2, epochs=50, batch_size=64)
# Out:
# Epoch 1/50
# 35/35 [==============================] - 7s 126ms/step - loss: 1.0870 - accuracy: 0.6125 - val_loss: 1.2431 - val_accuracy: 0.3714
# Epoch 2/50
# 35/35 [==============================] - 4s 113ms/step - loss: 0.4252 - accuracy: 0.8451 - val_loss: 0.6112 - val_accuracy: 0.8232
# Epoch 3/50
# 35/35 [==============================] - 4s 119ms/step - loss: 0.2471 - accuracy: 0.9237 - val_loss: 0.2911 - val_accuracy: 0.9161
# Epoch 4/50
# 35/35 [==============================] - 4s 122ms/step - loss: 0.1533 - accuracy: 0.9558 - val_loss: 0.0775 - val_accuracy: 0.9857
# Epoch 5/50
# 35/35 [==============================] - 4s 123ms/step - loss: 0.1303 - accuracy: 0.9616 - val_loss: 0.0921 - val_accuracy: 0.9750
# Epoch 6/50
# 35/35 [==============================] - 4s 106ms/step - loss: 0.1099 - accuracy: 0.9674 - val_loss: 0.2551 - val_accuracy: 0.9286
# Epoch 7/50
# 35/35 [==============================] - 4s 107ms/step - loss: 0.0694 - accuracy: 0.9821 - val_loss: 0.0344 - val_accuracy: 0.9875
# Epoch 8/50
# 35/35 [==============================] - 4s 107ms/step - loss: 0.0955 - accuracy: 0.9737 - val_loss: 0.1865 - val_accuracy: 0.9304
# Epoch 9/50
# 35/35 [==============================] - 4s 105ms/step - loss: 0.0671 - accuracy: 0.9795 - val_loss: 0.0942 - val_accuracy: 0.9696
# Epoch 10/50
# 35/35 [==============================] - 5s 146ms/step - loss: 0.0943 - accuracy: 0.9723 - val_loss: 0.0230 - val_accuracy: 0.9929
# Epoch 11/50
# 35/35 [==============================] - 6s 173ms/step - loss: 0.0571 - accuracy: 0.9830 - val_loss: 0.0686 - val_accuracy: 0.9804
# Epoch 12/50
# 35/35 [==============================] - 4s 118ms/step - loss: 0.0518 - accuracy: 0.9848 - val_loss: 0.0393 - val_accuracy: 0.9893
# Epoch 13/50
# 35/35 [==============================] - 6s 164ms/step - loss: 0.0279 - accuracy: 0.9915 - val_loss: 0.0096 - val_accuracy: 1.0000
# Epoch 14/50
# 35/35 [==============================] - 8s 215ms/step - loss: 0.0190 - accuracy: 0.9942 - val_loss: 0.0339 - val_accuracy: 0.9893
# Epoch 15/50
# 35/35 [==============================] - 5s 158ms/step - loss: 0.0234 - accuracy: 0.9942 - val_loss: 0.0348 - val_accuracy: 0.9875
# Epoch 16/50
# 35/35 [==============================] - 5s 140ms/step - loss: 0.0355 - accuracy: 0.9893 - val_loss: 0.0328 - val_accuracy: 0.9839
# Epoch 17/50
# 35/35 [==============================] - 5s 153ms/step - loss: 0.0201 - accuracy: 0.9920 - val_loss: 0.1605 - val_accuracy: 0.9554
# Epoch 18/50
# 35/35 [==============================] - 5s 135ms/step - loss: 0.0535 - accuracy: 0.9866 - val_loss: 0.1048 - val_accuracy: 0.9571
# Epoch 19/50
# 35/35 [==============================] - 4s 127ms/step - loss: 0.0344 - accuracy: 0.9902 - val_loss: 0.0372 - val_accuracy: 0.9875
# Epoch 20/50
# 35/35 [==============================] - 4s 123ms/step - loss: 0.0193 - accuracy: 0.9946 - val_loss: 0.0200 - val_accuracy: 0.9946
# Epoch 21/50
# 35/35 [==============================] - 4s 127ms/step - loss: 0.0209 - accuracy: 0.9942 - val_loss: 0.0028 - val_accuracy: 1.0000
# Epoch 22/50
# 35/35 [==============================] - 5s 135ms/step - loss: 0.0486 - accuracy: 0.9857 - val_loss: 0.0300 - val_accuracy: 0.9929
# Epoch 23/50
# 35/35 [==============================] - 4s 128ms/step - loss: 0.0435 - accuracy: 0.9888 - val_loss: 0.0191 - val_accuracy: 0.9911
# Epoch 24/50
# 35/35 [==============================] - 4s 104ms/step - loss: 0.0338 - accuracy: 0.9897 - val_loss: 0.0781 - val_accuracy: 0.9696
# Epoch 25/50
# 35/35 [==============================] - 5s 142ms/step - loss: 0.0350 - accuracy: 0.9893 - val_loss: 0.0119 - val_accuracy: 0.9964
# Epoch 26/50
# 35/35 [==============================] - 4s 119ms/step - loss: 0.0307 - accuracy: 0.9893 - val_loss: 0.0171 - val_accuracy: 0.9929
# Epoch 27/50
# 35/35 [==============================] - 5s 138ms/step - loss: 0.0209 - accuracy: 0.9946 - val_loss: 0.0190 - val_accuracy: 0.9964
# Epoch 28/50
# 35/35 [==============================] - 5s 145ms/step - loss: 0.0095 - accuracy: 0.9978 - val_loss: 0.0055 - val_accuracy: 0.9982
# Epoch 29/50
# 35/35 [==============================] - 4s 117ms/step - loss: 0.0052 - accuracy: 0.9987 - val_loss: 0.0018 - val_accuracy: 1.0000
# Epoch 30/50
# 35/35 [==============================] - 4s 125ms/step - loss: 0.0029 - accuracy: 0.9996 - val_loss: 0.0015 - val_accuracy: 1.0000
# Epoch 31/50
# 35/35 [==============================] - 4s 108ms/step - loss: 0.0299 - accuracy: 0.9915 - val_loss: 0.0337 - val_accuracy: 0.9893
# Epoch 32/50
# 35/35 [==============================] - 5s 130ms/step - loss: 0.0210 - accuracy: 0.9924 - val_loss: 0.0188 - val_accuracy: 0.9929
# Epoch 33/50
# 35/35 [==============================] - 5s 145ms/step - loss: 0.0314 - accuracy: 0.9897 - val_loss: 0.0072 - val_accuracy: 0.9982
# Epoch 34/50
# 35/35 [==============================] - 6s 169ms/step - loss: 0.0117 - accuracy: 0.9969 - val_loss: 0.0069 - val_accuracy: 0.9982
# Epoch 35/50
# 35/35 [==============================] - 5s 147ms/step - loss: 0.0065 - accuracy: 0.9973 - val_loss: 0.0037 - val_accuracy: 1.0000
# Epoch 36/50
# 35/35 [==============================] - 4s 125ms/step - loss: 0.0036 - accuracy: 0.9991 - val_loss: 5.3538e-04 - val_accuracy: 1.0000
# Epoch 37/50
# 35/35 [==============================] - 4s 119ms/step - loss: 0.0272 - accuracy: 0.9942 - val_loss: 0.0414 - val_accuracy: 0.9911
# Epoch 38/50
# 35/35 [==============================] - 5s 147ms/step - loss: 0.0241 - accuracy: 0.9942 - val_loss: 0.0081 - val_accuracy: 0.9982
# Epoch 39/50
# 35/35 [==============================] - 4s 121ms/step - loss: 0.0437 - accuracy: 0.9884 - val_loss: 0.0093 - val_accuracy: 0.9946
# Epoch 40/50
# 35/35 [==============================] - 4s 126ms/step - loss: 0.0203 - accuracy: 0.9937 - val_loss: 0.0211 - val_accuracy: 0.9929
# Epoch 41/50
# 35/35 [==============================] - 4s 110ms/step - loss: 0.0053 - accuracy: 0.9978 - val_loss: 3.8212e-04 - val_accuracy: 1.0000
# Epoch 42/50
# 35/35 [==============================] - 5s 134ms/step - loss: 0.0045 - accuracy: 0.9987 - val_loss: 3.3678e-04 - val_accuracy: 1.0000
# Epoch 43/50
# 35/35 [==============================] - 4s 112ms/step - loss: 5.3673e-04 - accuracy: 1.0000 - val_loss: 1.1109e-04 - val_accuracy: 1.0000
# Epoch 44/50
# 35/35 [==============================] - 6s 166ms/step - loss: 4.4158e-04 - accuracy: 1.0000 - val_loss: 9.7187e-05 - val_accuracy: 1.0000
# Epoch 45/50
# 35/35 [==============================] - 5s 136ms/step - loss: 3.0773e-04 - accuracy: 1.0000 - val_loss: 7.8236e-05 - val_accuracy: 1.0000
# Epoch 46/50
# 35/35 [==============================] - 4s 114ms/step - loss: 3.8644e-04 - accuracy: 1.0000 - val_loss: 6.4600e-05 - val_accuracy: 1.0000
# Epoch 47/50
# 35/35 [==============================] - 4s 105ms/step - loss: 2.8858e-04 - accuracy: 1.0000 - val_loss: 4.6749e-05 - val_accuracy: 1.0000
# Epoch 48/50
# 35/35 [==============================] - 4s 113ms/step - loss: 1.8771e-04 - accuracy: 1.0000 - val_loss: 4.2659e-05 - val_accuracy: 1.0000
# Epoch 49/50
# 35/35 [==============================] - 4s 105ms/step - loss: 3.5541e-04 - accuracy: 1.0000 - val_loss: 3.7689e-05 - val_accuracy: 1.0000
# Epoch 50/50
# 35/35 [==============================] - 4s 100ms/step - loss: 2.2309e-04 - accuracy: 1.0000 - val_loss: 3.4106e-05 - val_accuracy: 1.0000

# %%
epochs = list(range(50))
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

plt.plot(epochs, acc, label='train accuracy')
plt.plot(epochs, val_acc, label='val accuracy')
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.legend()
plt.show()

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']

plt.plot(epochs, loss, label='train loss')
plt.plot(epochs, val_loss, label='val loss')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()
